# %% [markdown]
# ### ISC catalog (International Seismological Center)
# I use **ISC FDSNWS event Web Service**. \
# You can check http://www.isc.ac.uk/fdsnws/event/1/help.php for more information.

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# **I get data  for Laptev sea region.** \
# http://www.isc.ac.uk/fdsnws/event/1/ \
# Below you can see the list of my parameters.

# %% [markdown]
# | min latitude | max latitude | min longitude | max longitude | start time (yyyy-mm-dd) | end time (yyyy-mm-dd) | format |
# | --- | --- | --- | --- | --- | --- | --- |
# | 70 | 80 | 100 | 150 | any | 2020-01-01 | xml |

# %%
response = requests.get('http://isc-mirror.iris.washington.edu/fdsnws/event/1/query?minlatitude=70&maxlatitude=80&minlongitude=100&maxlongitude=150&endtime=2020-01-01T00:00:00&catalog=ISC&format=xml&nodata=404')

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n\n<quakeml xmlns="http://quakeml.org/xmlns/quakeml/1.2">\n  <eventParameters publicID="smi:ISC/bulletin">\n    <creationInfo>\n      <agencyID>ISC</agencyID>\n      <creationTime>2020-04-14T20:45:41</creationTime>\n    </creationInfo>\n    <description>ISC Bulletin</description>\n    <comment>\n      <text>The ISC Bulletin has now been completely rebuilt for the\nperiod 1964-2010. As a result, the ISC hypocentre solutions and magnitudes for the entire period of 1964-latest\nare based on the ak135 velocity model and the location procedure\nthat is currently used in operations. The Bulletin has been cleaned up and a considerable number of previously\nunavailable data of permanent and temporary seismic deployments have been added.ISS station arrival data for years 1960 to 1963 have been provided by Antonio VillaseÃ\x83Â±or. (Antonio VillaseÃ\x83Â±or and E. Robert Engdahl, Systematic Relocation of Early Instrumental Seismicity: Earthquakes in the International Seismological Summary for 1960Ã¢Â\x80Â\x931963, Bull. Seism. Soc Am., 97, 1820Ã¢Â\x80Â\x931832, 2007). </text>\n    </comment>\n    <event publicID="smi:ISC/evid=914224">\n      <preferredOriginID>smi:ISC/origid=1961855</preferredOriginID>\n      <description>\n        <text>Laptev Sea</text>\n        <type>Flinn-Engdahl region</type>\n      </description>\n      <type>earthquake</type>\n      <typeCertainty>known</typeCertainty>\n      <origin publicID="smi:ISC/origid=1961855">\n        <time>\n          <value>1909-04-10T18:46:54Z</value>\n        </time>\n        <latitude>\n          <value>77.5000</value>\n        </latitude>\n        <longitude>\n          <value>128.0000</value>\n        </longitude>\n        <depth>\n          <value>35000.0</value>\n        </depth>\n        <depthType>operator assigned</depthType>\n        <creationInfo>\n          <author>GUTE</author>\n        </creationInfo>\n      </origin>\n      <magnitude publicID="smi:ISC/magid=1014939">\n        <mag>\n          <value>6.75</value>\n        </mag>\n        <type>MS</type>\n        <originID>smi:ISC/origid=1961855</originID>\n        <creationInfo>\n          <author>PAS</author>\n        </creationInfo>\n      </magnitude>\n    </event>\n    <event publicID="smi:ISC/evid=914115">\n      <preferredOriginID>smi:ISC/origid=1961746</preferredOriginID>\n      <description>\n        <text>Severnaya Zemlya</text>\n        <type>Flinn-Engdahl region</type>\n      </description>\n      <type>earthquake</type>\n      <typeCertainty>known</typeCertainty>\n      <origin publicID="smi:ISC/origid=1961746">\n        <time>\n          <value>1912-04-13T02:39:42Z</value>\n        </time>\n        <latitude>\n          <value>80.0000</value>\n        </latitude>\n        <longitude>\n          <value>100.0000</value>\n        </longitude>\n        <depth>\n          <value>35000.0</value>\n        </depth>\n        <depthType>operator assigned</depthType>\n        <creationInfo>\n          <author>GUTE</author>\n        </creationInfo>\n      </origin>\n      <magnitude publicID="smi:ISC/magid=1014830">\n        <mag>\n          <value>5.60</value>\n        </mag>\n        <type>MS</type>\n        <originID>smi:ISC/origid=1961746</originID>\n        <creationInfo>\n          <author>PAS</author>\n        </creationInfo>\n      </magnitude>\n    </event>\n    <event publicID="smi:ISC/evid=913357">\n      <preferredOriginID>smi:ISC/origid=605951299</preferredOriginID>\n      <description>\n        <text>Near north coast of eastern Siberia</text>\n        <type>Flinn-Engdahl region</type>\n      </description>\n      <type>earthquake</type>\n      <typeCertainty>known</typeCertainty>\n      <origin publicID="smi:ISC/origid=605951299">\n        <time>\n          <value>1918-11-30T06:48:46.86Z</value>\n          <uncertainty>1.59</uncertainty>\n        </time>\n        <latitude>\n          <value>70.5397</value>\n        </latitude>\n        <longitude>\n          <value ...

# %% [markdown]
# **Let's make our data look properly**

# %%
from xml.etree import ElementTree
from contextlib import suppress
 
 
# get_text_helper helps in getting nested text values from tree
def get_text_helper(element, paths, namespaces):
    try:
        for path in paths:
            element = element.find(path, namespaces=namespaces)
        return element.text
    except AttributeError:
        return None
 
 
def parse_xml(text):
    ns = dict(qml="http://quakeml.org/xmlns/quakeml/1.2")
    et = ElementTree.fromstring(text)
    for params in et.getchildren():
        info = params.find("qml:creationInfo", namespaces=ns)
        description = params.find("qml:description", namespaces=ns)
        comment = params.find("qml:comment", namespaces=ns)
        for event in params.findall("qml:event", namespaces=ns):
#           origin_id = event.find("qml:preferredOriginID", namespaces=ns).text
            kind = event.find("qml:type", namespaces=ns).text
            origin = event.find("qml:origin", namespaces=ns)
            time = get_text_helper(origin, ("qml:time", "qml:value"), ns)
            latitude = float(get_text_helper(origin, ("qml:latitude", "qml:value"), ns))
            longitude = float(get_text_helper(origin, ("qml:longitude", "qml:value"), ns))
            depth = None
            magnitude = None
            magtype = get_text_helper(event, ("qml:magnitude", "qml:type"), ns)
            # Ignore error when trying convert to float.
            with suppress(TypeError):
                depth = float(get_text_helper(origin, ("qml:depth", "qml:value"), ns))
                magnitude = float(get_text_helper(event, ("qml:magnitude", "qml:mag", "qml:value"), ns))
            yield dict(
                kind=kind,
                time=time,
                latitude=latitude,
                longitude=longitude,
                depth=depth,
                magnitude=magnitude,
                magtype=magtype
            )

# %%
isc_data = pd.DataFrame(data=parse_xml(response.text))
# Out:
# C:\Users\Home\Anaconda3\envs\seismic\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.

# %%
isc_data.head(3)
# Out:
#          kind                     time  latitude  longitude    depth  \
# 0  earthquake     1909-04-10T18:46:54Z   77.5000   128.0000  35000.0
# 1  earthquake     1912-04-13T02:39:42Z   80.0000   100.0000  35000.0
# 2  earthquake  1918-11-30T06:48:46.86Z   70.5397   130.5124  15000.0
#
#    magnitude magtype
# 0       6.75      MS
# 1       5.60      MS
# 2       6.40      MS

# %%
datetime = np.array(isc_data.time)
# get date
date = [datetime[i].split('T')[0] for i in range(len(datetime))]
# get time
time = [datetime[i].split('T')[1].split('Z')[0].split('.')[0] for i in range(len(datetime))]

# %%
isc_data = isc_data.rename(columns={'kind': 'date'})
isc_data['date'] = date
isc_data['time'] = time

# %%
# convert depth from m to km
isc_data['depth'] = [isc_data.depth[i] / 1000 for i in range(len(isc_data))]
# exclude events with no magnitude
isc_data = isc_data[isc_data['magnitude'].notnull()]

# %% [markdown]
# **Here, we have a table with basic info.\
# We load the data to isc_data.txt. So, we can use that info for further applications**

# %%
isc_data.head(3)
# Out:
#          date      time  latitude  longitude  depth  magnitude magtype
# 0  1909-04-10  18:46:54   77.5000   128.0000   35.0       6.75      MS
# 1  1912-04-13  02:39:42   80.0000   100.0000   35.0       5.60      MS
# 2  1918-11-30  06:48:46   70.5397   130.5124   15.0       6.40      MS

# %%
isc_data.to_csv('isc_data.txt', index=False)

# %% [markdown]
# **ISF is the IASPEI approved standard format for the exchange of parametric seismological data (hypocentres, magnitudes, phase arrivals, moment tensors, etc.).**

# %%
response = requests.get('http://isc-mirror.iris.washington.edu/fdsnws/event/1/query?minlatitude=70&maxlatitude=80&minlongitude=100&maxlongitude=150&endtime=2020-01-01T00:00:00&catalog=ISC&format=isf&nodata=404')

# %%
response.text
# Out:
# 'DATA_TYPE EVENT IMS1.0\nISC Bulletin\nEvent   914224 Laptev Sea\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1909/04/10 18:46:54                  77.5000  128.0000                  35.0                                       uk GUTE       1961855\n\nMagnitude  Err Nsta Author      OrigID\nMS     6.8          PAS        1961855\n\nEvent   914115 Severnaya Zemlya\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1912/04/13 02:39:42                  80.0000  100.0000                  35.0                                       uk GUTE       1961746\n\nMagnitude  Err Nsta Author      OrigID\nMS     5.6          PAS        1961746\n\nEvent   913357 Near north coast of eastern Siberia\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1918/11/30 06:48:46.86   1.59 3.810  70.5397  130.5124 56.72 12.47  70  15.0f        13   27 196  31.96  59.46 m i ke ISC       05951299\n\nMagnitude  Err Nsta Author      OrigID\nMS     6.4 0.3    3 ISC       05951299\n\nEvent   912026 Near coast of northern Siberia\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1922/09/24 12:26:00                  75.0000  100.0000                                                             uk ISS        1959184\n\nEvent   911385 Laptev Sea\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1923/05/30 08:30:40                  77.0000  127.0000                  35.0                                       uk GUTE       1958464\n\nMagnitude  Err Nsta Author      OrigID\nMS     6.0          PAS        1958464\n\nEvent   911386 Laptev Sea\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1923/05/30 17:56:42                  77.0000  127.0000                  35.0                                       uk GUTE       1958466\n\nMagnitude  Err Nsta Author      OrigID\nMS     6.0          PAS        1958466\n\nEvent   911165 Severnaya Zemlya\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1924/10/19 15:34:45                  79.0000  110.0000                                                             uk ISS        1958211\n\nEvent   909808 Near coast of northern Siberia\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1926/04/09 10:04:50                  74.0000  125.0000                  35.0                                       uk GUTE       1956608\n\nMagnitude  Err Nsta Author      OrigID\nMS     5.8          PAS        1956608\n\nEvent   909048 East of Severnaya Zemlya\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1927/01/07 10:43:12                  80.0000  117.0000                  35.0                                       uk GUTE       1955685\n\nMagnitude  Err Nsta Author      OrigID\nMS     5.6          PAS        1955685\n\nEvent   909622 Northern and central Siberia\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdist  Mdist Qual   Author      OrigID\n1927/11/14 00:12:08.45   0.55 3.202  70.2211  128.9387 9.961 7.898  81  15.0f       161  110 136  21.29 128.11 m i ke ISC       05951716\n\nMagnitude  Err Nsta Author      OrigID\nMS     6.6 0.2   12 ISC       05951716\n\nEvent   909623 Northern and central Siberia\n   Date       Time        Err   RMS Latitude Longitude  Smaj  Smin  Az Depth   Err Ndef Nsta Gap  mdi ...

# %% [markdown]
# **So, we have the possibility to get more information. Let's keep it in mind for further applications.**

# %% [markdown]
# ### United States Geological Survey (NEIC)
# You can check https://earthquake.usgs.gov/fdsnws/event/1/ for more information.

# %% [markdown]
# | min latitude | max latitude | min longitude | max longitude | start time (yyyy-mm-dd) | end time (yyyy-mm-dd) |
# | --- | --- | --- | --- | --- | --- |
# | 70 | 80 | 100 | 150 | 1970-01-01 | 2020-01-01 |

# %%
response = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=text&starttime=1970-01-01&endtime=2020-01-01&minlatitude=70&minlongitude=100&maxlatitude=80&maxlongitude=150&orderby=time')

# %%
response.text
# Out:
# "#EventID|Time|Latitude|Longitude|Depth/km|Author|Catalog|Contributor|ContributorID|MagType|Magnitude|MagAuthor|EventLocationName\nus600050jx|2019-08-04T13:22:56.174|71.4671|138.4826|10|us|us|us|us600050jx|mb|4.3|us|193km NNE of Ust'-Kuyga, Russia\nus70003ntt|2019-05-21T03:45:11.918|75.493|110.1978|10|us|us|us|us70003ntt|mb|4.8|us|167km NNW of Nordvik, Russia\nus70003k5r|2019-05-13T00:43:33.365|79.4127|123.9058|10|us|us|us|us70003k5r|mww|5.4|us|East of Severnaya Zemlya\nus1000g56d|2018-08-08T03:06:10.780|71.9804|134.4512|15.07|us|us|us|us1000g56d|mb|4.4|us|196km ENE of Tiksi, Russia\nus1000dt51|2018-04-27T00:27:47.080|79.401|123.8181|10|us|us|us|us1000dt51|mb|4.6|us|East of Severnaya Zemlya\nus1000d2cr|2018-03-03T00:55:17.630|72.1417|133.8758|13.71|us|us|us|us1000d2cr|mb|4.1|us|180km ENE of Tiksi, Russia\nus2000cqxp|2018-01-16T07:46:04.860|71.9898|127.7396|15.35|us|us|us|us2000cqxp|mb|4.4|us|51km NW of Tiksi, Russia\nus20008lpv|2017-02-23T07:47:12.740|74.4295|114.0094|10|us|us|us|us20008lpv|mb|4.3|us|87km ENE of Nordvik, Russia\nus200081ji|2016-12-10T01:45:35.130|75.0808|133.2404|10|us|us|us|us200081ji|mb|4.4|us|Laptev Sea\nus10007eay|2016-11-24T22:50:45.630|72.7583|124.6821|10|us|us|us|us10007eay|mb|4|us|186km NW of Tiksi, Russia\nus10006gg2|2016-08-19T09:59:26.180|71.8244|129.8185|18.95|us|us|us|us10006gg2|mb|4.7|us|36km ENE of Tiksi, Russia\nus10004wta|2016-03-09T19:05:07.470|74.8268|134.511|14.53|us|us|us|us10004wta|mb|4|us|Laptev Sea\nus10003n0p|2015-09-30T04:47:11.860|74.8326|134.0855|15.26|us|us|us|us10003n0p|mb|4.3|us|Laptev Sea\nus20003hqm|2015-09-10T12:41:46.490|70.2498|128.3024|21.58|us|us|us|us20003hqm|mb|4.6|us|161km S of Tiksi, Russia\nus1000350h|2015-08-09T10:11:01.240|77.0175|125.2453|10|us|us|us|us1000350h|mb|4.5|us|Laptev Sea\nus20002mad|2015-05-26T04:41:24.880|75.3898|112.0005|14.98|us|us|us|us20002mad|mb|4.2|us|152km N of Nordvik, Russia\nusc000tcgy|2014-12-12T07:42:57.640|74.2143|130.4642|10|us|us|us|usc000tcgy|mb|4.4|us|286km N of Tiksi, Russia\nusc000rk3s|2014-06-22T23:58:23.870|78.4758|125.8772|10|us|us|us|usc000rk3s|mb|4.9|us|East of Severnaya Zemlya\nusc000rn2r|2014-06-09T13:13:04.760|73.3303|124.6914|14.98|us|us|us|usc000rn2r|mb|4.5|us|230km NW of Tiksi, Russia\nusc000r9su|2014-06-01T08:52:44.100|75.0782|133.6472|10|us|us|us|usc000r9su|mb|4.7|us|Laptev Sea\nusc000r8g7|2014-05-29T05:07:33.450|70.8438|139.7606|10|us|us|us|usc000r8g7|mb|4.8|us|172km N of Deputatskiy, Russia\nusb000qpsn|2014-04-11T13:27:05.920|74.9161|133.9098|10|us|us|us|usb000qpsn|mb|4.2|us|Laptev Sea\nusc000meer|2014-01-14T03:43:05.100|78.7939|125.882|10|us|us|us|usc000meer|mb|4.1|us|East of Severnaya Zemlya\nusb000k1kl|2013-09-28T14:37:33.410|77.168|129.6752|10.06|us|us|us|usb000k1kl|mb|4.6|us|Laptev Sea\nusb000jmgy|2013-09-09T19:04:18.150|76.2069|133.4011|14.47|us|us|us|usb000jmgy|mb|4.6|us|Laptev Sea\nusb000j2wv|2013-08-07T18:29:13.290|75.9508|132.3474|10|us|us|us|usb000j2wv|mb|4.5|us|Laptev Sea\nusp000k065|2013-04-11T20:01:08.510|74.297|130.057|10|us|us|us|usp000k065|mb|4.5|us|Laptev Sea\nus2013nbb5|2013-03-22T06:39:15.830|78.081|125.855|10|us|us|us|us2013nbb5|mb|4.3|us|East of Severnaya Zemlya\nusp000jz3y|2013-02-07T03:33:48.620|74.318|129.947|10|us|us|us|usp000jz3y|mb|4.3|us|near the coast of northwestern Sakha, Russia\nusp000jph5|2012-07-27T14:01:27.420|79.192|123.954|10|us|us|us|usp000jph5|mb|4.4|us|east of Severnaya Zemlya\nusp000jhbq|2012-04-07T00:15:00.770|74.964|136.45|10|us|us|us|usp000jhbq|mb|4.4|us|New Siberian Islands, Sakha, Russia\nusp000jhbp|2012-04-07T00:12:19.920|75.135|136.429|10|us|us|us|usp000jhbp|mb|4.4|us|New Siberian Islands, Sakha, Russia\nusp000jh9q|2012-04-05T18:42:30.210|75.054|136.513|10|us|us|us|usp000jh9q|mb|4.7|us|New Siberian Islands, Sakha, Russia\nusp000jcqn|2011-12-27T20:25:36.020|74.068|134.203|10|us|us|us|usp000jcqn|mb|4.7|us|Laptev Sea\nusp000j8qv|2011-09-29T16:08:14.420|79.817|123.865|10|us|us|us|usp000j8qv|mb|4.4|us|east of Severnaya Zemlya\nusp000j6q8|2011-08-20T05:57:41.310|79.361|124.16|1 ...

# %%
usgs_data = response.text.split('\n')

for line in range(len(usgs_data)):
    usgs_data[line] = usgs_data[line].split('|')

usgs_data = pd.DataFrame(usgs_data[1:-1], columns=usgs_data[0])

# %%
usgs_data = usgs_data.rename(columns={'#EventID': 'date', 'Time': 'time', 'Latitude': 'latitude', 'Longitude': 'longitude',
                                      'Depth/km': 'depth', 'Magnitude': 'magnitude', 'MagType':'magtype'})

# %%
usgs_data.head(2)
# Out:
#          date                     time latitude longitude depth Author  \
# 0  us600050jx  2019-08-04T13:22:56.174  71.4671  138.4826    10     us
# 1  us70003ntt  2019-05-21T03:45:11.918   75.493  110.1978    10     us
#
#   Catalog Contributor ContributorID magtype magnitude MagAuthor  \
# 0      us          us    us600050jx      mb       4.3        us
# 1      us          us    us70003ntt      mb       4.8        us
#
#                  EventLocationName
# 0  193km NNE of Ust'-Kuyga, Russia
# 1     167km NNW of Nordvik, Russia

# %%
datetime = np.array(usgs_data.time)
# get date
date = [datetime[i].split('T')[0] for i in range(len(datetime))]
# get time
time = [datetime[i].split('T')[1].split('.')[0] for i in range(len(datetime))]

usgs_data['date'] = date
usgs_data['time'] = time

# %%
usgs_data = usgs_data[['date', 'time', 'latitude', 'longitude', 'depth', 'magnitude', 'magtype']]

# %%
usgs_data.head(3)
# Out:
#          date      time latitude longitude depth magnitude magtype
# 0  2019-08-04  13:22:56  71.4671  138.4826    10       4.3      mb
# 1  2019-05-21  03:45:11   75.493  110.1978    10       4.8      mb
# 2  2019-05-13  00:43:33  79.4127  123.9058    10       5.4     mww

# %% [markdown]
# **Here, we have a table with basic info.\
# We load the data to isc_data.txt. So, we can use that info for further applications**

# %%
usgs_data.to_csv('usgs_data.txt', index=False)
